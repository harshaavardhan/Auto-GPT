# %% [markdown]
# <a href="https://colab.research.google.com/github/harshaavardhan/Auto-GPT/blob/master/Twitter_Algorithm_Code_Reader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Link: https://python.langchain.com/en/latest/use_cases/code/twitter-the-algorithm-analysis-deeplake.html

# %%
# !python3 -m pip install --upgrade langchain deeplake openai tiktoken
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
import getpass

from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import DeepLake

#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

os.environ['OPENAI_API_KEY'] = getpass.getpass('OpenAI API Key:')
os.environ['ACTIVELOOP_TOKEN'] = getpass.getpass('Activeloop Token:')
# Out:
# OpenAI API Key:··········
# Activeloop Token:··········

# %%
embeddings = OpenAIEmbeddings(disallowed_special=())

# %%
# !git clone https://github.com/twitter/the-algorithm # replace any repository of your choice
# Out:
# Cloning into 'the-algorithm'...
# remote: Enumerating objects: 7615, done.
# remote: Counting objects: 100% (911/911), done.
# remote: Compressing objects: 100% (573/573), done.
# remote: Total 7615 (delta 224), reused 887 (delta 213), pack-reused 6704
# Receiving objects: 100% (7615/7615), 6.35 MiB | 13.09 MiB/s, done.
# Resolving deltas: 100% (2436/2436), done.

# %%
import os
from langchain.document_loaders import TextLoader

root_dir = './the-algorithm'


docs = []
for dirpath, dirnames, filenames in os.walk(root_dir):
    for file in filenames:
        try: 
            loader = TextLoader(os.path.join(dirpath, file), encoding='utf-8')
            docs.extend(loader.load_and_split())
        except Exception as e: 
            pass
# Out:
# "\nHere's a breakdown of what the code does:\n\nIt initializes an empty list called docs to store the loaded and split documents.\nIt uses the os.walk() function to traverse the directory specified by root_dir.\nIn each iteration of the loop, it retrieves the current dirpath, dirnames, and filenames.\nFor each file in filenames, it attempts to load and split the file's contents using a TextLoader object. The os.path.join(dirpath, file) constructs the full path to the file.\nIf the loading and splitting are successful, it extends the docs list with the loaded and split documents using docs.extend(loader.load_and_split()).\nIf an exception occurs during loading and splitting, the code catches the exception and continues to the next file using the except block and the pass statement.\n"

# %% [markdown]
# root is a string representing the current directory being traversed.
# directories is a list containing the names of the directories within the current directory.
# files is a list containing the names of the files within the current directory.
#
# '''
# Here's a breakdown of what the code does:
#
# It initializes an empty list called docs to store the loaded and split documents.
# It uses the os.walk() function to traverse the directory specified by root_dir.
# In each iteration of the loop, it retrieves the current dirpath, dirnames, and filenames.
# For each file in filenames, it attempts to load and split the file's contents using a TextLoader object. The os.path.join(dirpath, file) constructs the full path to the file.
# If the loading and splitting are successful, it extends the docs list with the loaded and split documents using docs.extend(loader.load_and_split()).
# If an exception occurs during loading and splitting, the code catches the exception and continues to the next file using the except block and the pass statement.
# '''

# %%
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_documents(docs)
# Out:
# WARNING:langchain.text_splitter:Created a chunk of size 1983, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2425, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2095, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1051, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1047, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1293, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1433, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2151, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2046, which is longer than the specified 1000
# ...

# %%
username = "harshaavardhan23" # replace with your username from app.activeloop.ai
db = DeepLake(dataset_path=f"hub://{username}/twitter-algorithm", embedding_function=embeddings, public=False) #dataset would be publicly available
db.add_documents(texts)
# Out:
# Your Deep Lake dataset has been successfully created!
# The dataset is private so make sure you are logged in!
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/harshaavardhan23/twitter-algorithm
# hub://harshaavardhan23/twitter-algorithm loaded successfully.
# Evaluating ingest: 100%|██████████| 26/26 [02:14<00:00
# Dataset(path='hub://harshaavardhan23/twitter-algorithm', tensors=['embedding', 'ids', 'metadata', 'text'])
#
#   tensor     htype       shape       dtype  compression
#   -------   -------     -------     -------  -------
#  embedding  generic  (25747, 1536)  float32   None
#     ids      text     (25747, 1)      str     None
#  metadata    json     (25747, 1)      str     None
#    text      text     (25747, 1)      str     None
# ['4bddb042-f1b2-11ed-8ce7-0242ac1c000c',
#  '4bddb2ae-f1b2-11ed-8ce7-0242ac1c000c',
#  '4bddb33a-f1b2-11ed-8ce7-0242ac1c000c',
#  '4bddb3a8-f1b2-11ed-8ce7-0242ac1c000c',
# ...

# %%
db = DeepLake(dataset_path=f"hub://{username}/twitter-algorithm", read_only=True, embedding_function=embeddings)
retriever = db.as_retriever()
retriever.search_kwargs['distance_metric'] = 'cos'
retriever.search_kwargs['fetch_k'] = 100
retriever.search_kwargs['maximal_marginal_relevance'] = True
retriever.search_kwargs['k'] = 10
# Out:
# /
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/harshaavardhan23/twitter-algorithm
# \
# hub://harshaavardhan23/twitter-algorithm loaded successfully.
# WARNING:langchain.chat_models.openai:WARNING! model is not default parameter.
#                     model was transferred to model_kwargs.
#                     Please confirm that model is what you intended.
# Deep Lake Dataset in hub://harshaavardhan23/twitter-algorithm already exists, loading from the storage
# Dataset(path='hub://harshaavardhan23/twitter-algorithm', read_only=True, tensors=['embedding', 'ids', 'metadata', 'text'])
#
#   tensor     htype       shape       dtype  compression
#   -------   -------     -------     -------  -------
#  embedding  generic  (25747, 1536)  float32   None
#     ids      text     (25747, 1)      str     None
#  metadata    json     (25747, 1)      str     None
#    text      text     (25747, 1)      str     None
# ...

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import ConversationalRetrievalChain

model = ChatOpenAI(model_name='gpt-3.5-turbo') # switch to 'gpt-4'
qa = ConversationalRetrievalChain.from_llm(model,retriever=retriever)

# %%
questions = [
    "What does favCountParams do?",
    "is it Likes + Bookmarks, or not clear from the code?",
    "What are the major negative modifiers that lower your linear ranking parameters?",   
    "How do you get assigned to SimClusters?",
    "What is needed to migrate from one SimClusters to another SimClusters?",
    "How much do I get boosted within my cluster?",   
    "How does Heavy ranker work. what are it’s main inputs?",
    "How can one influence Heavy ranker?",
    "why threads and long tweets do so well on the platform?",
    "Are thread and long tweet creators building a following that reacts to only threads?",
    "Do you need to follow different strategies to get most followers vs to get most likes and bookmarks per tweet?",
    "Content meta data and how it impacts virality (e.g. ALT in images).",
    "What are some unexpected fingerprints for spam factors?",
    "Is there any difference between company verified checkmarks and blue verified individual checkmarks?",
] 
chat_history = []

for question in questions:  
    result = qa({"question": question, "chat_history": chat_history})
    chat_history.append((question, result['answer']))
    print(f"-> **Question**: {question} \n")
    print(f"**Answer**: {result['answer']} \n")
# Out:
# -> **Question**: What does favCountParams do?
#
# **Answer**: Unfortunately, based on the given context, I can't determine the specific function of `favCountParams`. The given context contains several sections of code with different objects, functions, and variables, and none of them seem to be directly related to `favCountParams`. Could you please provide more information or context?
#
# -> **Question**: is it Likes + Bookmarks, or not clear from the code?
#
# ...
